# %% [markdown]
# **Consider the following Python dictionary data and Python list labels:**
#
# data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'],
#         'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4],
#         'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
import pandas as pd
import numpy as np

data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'],
        'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4],
        'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data)
df
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 1      Cranes  4.0       4      yes
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      yes
# 4  spoonbills  6.0       3       no
# 5      Cranes  3.0       4       no
# 6     plovers  5.5       2       no
# 7      Cranes  NaN       2      yes
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no

# %% [markdown]
# **1. Create a DataFrame birds from this dictionary data which has the index labels.**

# %%
pd.DataFrame(df.birds)
# Out:
#         birds
# 0      Cranes
# 1      Cranes
# 2     plovers
# 3  spoonbills
# 4  spoonbills
# 5      Cranes
# 6     plovers
# 7      Cranes
# 8  spoonbills
# 9  spoonbills

# %% [markdown]
# **2. Display a summary of the basic information about birds DataFrame and its data.**

# %%
df['birds'].describe()
# Out:
# count             10
# unique             3
# top       spoonbills
# freq               4
# Name: birds, dtype: object

# %% [markdown]
# **3. Print the first 2 rows of the birds dataframe **

# %%
#.loc is used for accesing rows based on index
#.iloc is used for accesing rows based on row numbers(number of rows)
pd.DataFrame(df['birds'].iloc[:2])
# Out:
#     birds
# 0  Cranes
# 1  Cranes

# %% [markdown]
# **4. Print all the rows with only 'birds' and 'age' columns from the dataframe**

# %%
#df[['birds','age']]
df1 = df.iloc[:,0:2] 
df1
# Out:
#         birds  age
# 0      Cranes  3.5
# 1      Cranes  4.0
# 2     plovers  1.5
# 3  spoonbills  NaN
# 4  spoonbills  6.0
# 5      Cranes  3.0
# 6     plovers  5.5
# 7      Cranes  NaN
# 8  spoonbills  8.0
# 9  spoonbills  4.0

# %% [markdown]
# **5. select [2, 3, 7] rows and in columns ['birds', 'age', 'visits']**

# %%
df.iloc[[2, 3, 7]]
# Out:
#         birds  age  visits priority
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      yes
# 7      Cranes  NaN       2      yes

# %% [markdown]
# **6. select the rows where the number of visits is less than 4**

# %%
df[df['visits']<4]
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 2     plovers  1.5       3       no
# 4  spoonbills  6.0       3       no
# 6     plovers  5.5       2       no
# 7      Cranes  NaN       2      yes
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no

# %% [markdown]
# **7. select the rows with columns ['birds', 'visits'] where the age is missing i.e NaN**

# %%
df[df['age'].isnull()]
# Out:
#         birds  age  visits priority
# 3  spoonbills  NaN       4        1
# 7      Cranes  NaN       2        1

# %% [markdown]
# **8. Select the rows where the birds is a Cranes and the age is less than 4**

# %%
df[(df['age']<4) & (df ['birds'] == 'Cranes')]
# Out:
#     birds  age  visits priority
# 0  Cranes  3.5       2      yes
# 5  Cranes  3.0       4       no

# %% [markdown]
# **9. Select the rows the age is between 2 and 4(inclusive)**

# %%
df[df['age'] <5]
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 1      Cranes  4.0       4      yes
# 2     plovers  1.5       3       no
# 5      Cranes  3.0       4       no
# 9  spoonbills  4.0       2       no

# %% [markdown]
# **10. Find the total number of visits of the bird Cranes**

# %%
df1 = df.groupby('birds')
df1

# %%
df1 = df.groupby('birds')
for birds, birds_1 in df1:
    print (birds)
    print(birds_1)
print ('total number of birds visits:' , df1['visits'].sum())
# Out:
# Cranes
#     birds  age  visits priority
# 0  Cranes  3.5       2      yes
# 1  Cranes  4.0       4      yes
# 5  Cranes  3.0       4       no
# 7  Cranes  NaN       2      yes
# plovers
#      birds  age  visits priority
# 2  plovers  1.5       3       no
# 6  plovers  5.5       2       no
# spoonbills
#         birds  age  visits priority
# 3  spoonbills  NaN       4      yes
# 4  spoonbills  6.0       3       no
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no
# total number of birds visits: birds
# Cranes        12
# plovers        5
# spoonbills    12
# Name: visits, dtype: int64

# %% [markdown]
# **11. Calculate the mean age for each different birds in dataframe.**

# %%
df1['age'].mean()
# Out:
# birds
# Cranes        3.5
# plovers       3.5
# spoonbills    6.0
# Name: age, dtype: float64

# %% [markdown]
# **12. Append a new row 'k' to dataframe with your choice of values for each column. Then delete that row to return the original DataFrame.**

# %%
df.loc['10'] = ['plover', 2, 1, 'no']
df
# Out:
#          birds  age  visits priority
# 0       Cranes  3.5       2        1
# 1       Cranes  4.0       4        1
# 2      plovers  1.5       3        0
# 3   spoonbills  NaN       4        1
# 4   spoonbills  6.0       3        0
# 5       Cranes  3.0       4        0
# 6      plovers  5.5       2        0
# 7       Cranes  NaN       2        1
# 8   spoonbills  8.0       3        0
# 9   spoonbills  4.0       2        0
# 10      plover  2.0       1       no

# %%
df.drop(df.index[10])
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2        1
# 1      Cranes  4.0       4        1
# 2     plovers  1.5       3        0
# 3  spoonbills  NaN       4        1
# 4  spoonbills  6.0       3        0
# 5      Cranes  3.0       4        0
# 6     plovers  5.5       2        0
# 7      Cranes  NaN       2        1
# 8  spoonbills  8.0       3        0
# 9  spoonbills  4.0       2        0

# %% [markdown]
# **13. Find the number of each type of birds in dataframe (Counts)**

# %%
df.groupby('birds').size()
# Out:
# birds
# Cranes        4
# plovers       2
# spoonbills    4
# dtype: int64

# %% [markdown]
# **14. Sort dataframe (birds) first by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order.**

# %%
df.sort_values(by='age', ascending=False)
# Out:
#         birds  age  visits priority
# 8  spoonbills  8.0       3       no
# 4  spoonbills  6.0       3       no
# 6     plovers  5.5       2       no
# 1      Cranes  4.0       4      yes
# 9  spoonbills  4.0       2       no
# 0      Cranes  3.5       2      yes
# 5      Cranes  3.0       4       no
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      yes
# 7      Cranes  NaN       2      yes

# %%
df.sort_values(by='visits')
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 6     plovers  5.5       2       no
# 7      Cranes  NaN       2      yes
# 9  spoonbills  4.0       2       no
# 2     plovers  1.5       3       no
# 4  spoonbills  6.0       3       no
# 8  spoonbills  8.0       3       no
# 1      Cranes  4.0       4      yes
# 3  spoonbills  NaN       4      yes
# 5      Cranes  3.0       4       no

# %% [markdown]
# **15. Replace the priority column values with'yes' should be 1 and 'no' should be 0**

# %%
df['priority'].replace(['yes' == 1, 'no' == 0])
df
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 1      Cranes  4.0       4      yes
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      yes
# 4  spoonbills  6.0       3       no
# 5      Cranes  3.0       4       no
# 6     plovers  5.5       2       no
# 7      Cranes  NaN       2      yes
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no

# %% [markdown]
# **16. In the 'birds' column, change the 'Cranes' entries to 'trumpeters'.**

# %%
#df.replace([df['birds'] == 'Cranes'] == 'trump')
df.replace('Cranes', 'trumpeters')
# Out:
#         birds  age  visits priority
# 0  trumpeters  3.5       2      yes
# 1  trumpeters  4.0       4      yes
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      yes
# 4  spoonbills  6.0       3       no
# 5  trumpeters  3.0       4       no
# 6     plovers  5.5       2       no
# 7  trumpeters  NaN       2      yes
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no
